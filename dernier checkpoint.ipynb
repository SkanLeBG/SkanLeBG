# %%
name1=list(str(input("enter your name: ")))
name2=list(str(input("enter your name: ")))
def soustraction (name1,name2):
    for n in range (0,len(name1)-1):
        for i in range (0,len(name2)-1):
            if name1[n-1]==name2[i-1]:
                c=name1[n-1]
                name1.remove(c)
                name2.remove(c)
                name3=name1+name2
                return name3 
name3=soustraction(name1,name2)
print(name3)
h=len(name3)
flames=list('flames')
x=list('flames')
h1=len(flames)

print (flames)
def jeux (flames,name3,h,h1,x):
    soustraction(name1,name2)
    
    
    while h>h1-1:
        h=(h-1)-h1
    flames.remove(flames[h])
    print(flames)
    h=len(name3)
    h1=(len(flames))*-1
    
    
    while h>=h1:
        h=h1+h
    if h<=h1:
        h=h+h1*-1
    
    flames.remove(flames[h])
    print(flames)
    h=len(name3)
    
    h1=len(flames)
    
    
    while h>h1-1:
        h=(h-1)-h1
        
    
    flames.remove(flames[h])
    print(flames)
    
    h=len(name3)
    h1=(len(flames))
    while h>=h1-1:
        h=(h-1)-h1
        if h<h1-1:
            h=h-h1
            if h<h1-1:
                h=h+h1
    flames.remove(flames[h])
    print(flames)
    h=len(name3)
    h1=(len(flames))
    while h>=h1-1:
        h=(h-1)-h1
        if h<h1-1:
            h=h-h1
            if h<h1-1:
                h=h+h1
    flames.remove(flames[h])
    res=flames
    print(res)
    if res==['f']:
        print("Friend")
    elif res==['l']:
        print("Love")
    elif res==['a']:
        print("Affection")
    elif res==['m']:
        print("Marriage")
    elif res==['e']:
        print("Enemy")
    else:
        print("Siblings")
    
    
    
jeux(flames,name3,h,h1,x)
# Out:
# enter your name: skander
# enter your name: mohamed
# ['s', 'k', 'n', 'd', 'e', 'r', 'm', 'o', 'h', 'm', 'e', 'd']
# ['f', 'l', 'a', 'm', 'e', 's']
# ['f', 'l', 'a', 'm', 'e']
# ['f', 'l', 'm', 'e']
# ['f', 'l', 'e']
# ['l', 'e']
# ['e']
# Enemy
